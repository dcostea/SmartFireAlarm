// %% [markdown]
// # PREPARE DATA
// (build data preparation pipeline and training pipeline)

// %%
#r "nuget:Microsoft.ML,1.5.2"
using XPlot.Plotly;
using System.Linq;
using Microsoft.ML;
using Microsoft.ML.Data;

MLContext mlContext = new MLContext(seed: 123);
// Out:
// Installed package Microsoft.ML version 1.5.2

// %% [markdown]
// ### Load data models from Models.csx file

// %%
#load "C:\Users\dcost\source\repos\SmartFireAlarm\SmartFireAlarm\Jupyter\Models.csx"

// %% [markdown]
// ### Load data from csv file into a dataview

// %%
const string DATASET_PATH = "./sensors_data.csv";
IDataView data = mlContext.Data.LoadFromTextFile<ModelInput>(
    path: DATASET_PATH,
    hasHeader: true,
    separatorChar: ',');

// %% [markdown]
// ### Shuffle and split data to _trainingData_ and _testingData_ by a fraction of 0.2

// %%
var shuffledData = mlContext.Data.ShuffleRows(data, seed: 1);
var split = mlContext.Data.TrainTestSplit(shuffledData, testFraction: 0.2);
var trainingData = split.TrainSet;
var testingData = split.TestSet;

// %% [markdown]
// ### Selected features for building the model

// %%
var featureColumns = new[] { "Temperature", "Luminosity", "Infrared", "Distance", "Hour", "Day" };

// %% [markdown]
// ### Build the pre-processing pipeline
// > Map value (string) to key (number)
// > Custom mapping (extract HourOfDay and DayofYear from CreatedAt feature)
// > Concatenate features
// > Normalize features

// %%
var preprocessingPipeline = mlContext.Transforms.Conversion.MapValueToKey("Label")
    .Append(mlContext.Transforms.CustomMapping<CustomInputRow, CustomOutputRow>
        (CustomMappings.IncomeMapping, nameof(CustomMappings.IncomeMapping)))
    .Append(mlContext.Transforms.Concatenate("Features", featureColumns))
    .Append(mlContext.Transforms.NormalizeMinMax("Features"));

// %% [markdown]
// ### Box plot segmentation (for normalized data!)

// %%
var normalizedData = preprocessingPipeline.Fit(trainingData).Transform(trainingData);
var normalizedFeatures = normalizedData.GetColumn<float[]>("Features").ToArray();

var normalizedTemperatures = normalizedFeatures.Select(f => f[0]);
var normalizedLuminosities = normalizedFeatures.Select(f => f[1]);
var normalizedInfrareds = normalizedFeatures.Select(f => f[2]);
var normalizedDistances = normalizedFeatures.Select(f => f[3]);
var normalizedHours = normalizedFeatures.Select(f => f[4]);
var normalizedDays = normalizedFeatures.Select(f => f[5]);

// %%
var segmentationNormalizedFeatures = Chart.Plot(new[] {
    new Graph.Box { y = normalizedTemperatures, name = "Temperature" },
    new Graph.Box { y = normalizedLuminosities, name = "Luminosity" },
    new Graph.Box { y = normalizedInfrareds, name = "Infrared" },
    new Graph.Box { y = normalizedDistances, name = "Distance" },
    new Graph.Box { y = normalizedHours, name = "Hour of Day" },
    new Graph.Box { y = normalizedDays, name = "Day of Year" }
});

var layout = new Layout.Layout()
{
    title = "Box plot segmentation"
};
segmentationNormalizedFeatures.WithLayout(layout);

display(segmentationNormalizedFeatures);
// Out:
// <div id="f36b0364-8683-4d3c-bcf5-fd608075e75b" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = require.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}}) || require;
//     xplotRequire(['plotly'], function(Plotly) {
//
//             var data = [{"type":
934486,0.19851165,0.20468135,0.17389646,0.1595853,0.20468135,0.19234194,0.68432766,0.16162066,0.20468135,0.19030659,0.17389646,0.20468135,0.1535428,0.20468135,0.17389646,0.21078743,0.19234194,0.20054701,0.2067167,0.2067167,0.1595853,0.1595853,0.6966035,0.17599542,0.19234194,0.16162066,0.17389646,0.2067167,0.2067167,0.41292456,0.1595853,0.17389646,0.17389646,0.20468135,0.1535428,0.2067167,0.61461645,0.15990332,0.15545097,0.2067167,0.20468135,0.2067167,0.1646737,0.3727261,0.57976085,0.1646737,0.14807278,0.19234194,0.17599542,0.5859306,0.20468135,0.14807278,0.2067167,0.2067167,0.15754993,0.1595853,0.15812239,0.16263834,0.17389646,0.1595853,0.20264599,0.15754993,0.14934486,0.15545097,0.20468135,0.15545097,0.16779035,0.2189925,0.19234194,0.20468135,0.2067167,0.2067167,0.19234194,0.15754993,0.17389646,0.17389646,0.15754993,0.19234194,0.14807278,0.17599542,0.20468135,0.23133188,0.1595853,0.23336725,0.15545097,0.20468135,0.19444092,0.20468135,0.6187508,0.20054701,0.20468135,0.59820634,0.15754993,0.19234194,0.15506932,0.3563796,0.1595853,0.20468135,0.2067167,0.1595853,0.14934486,0.15754993,0.20468135,0.15754993,0.1595853,0.27229363,0.23743801,0.2067167,0.23540261,0.20264599,0.1595853,0.20468135,0 ...

// %% [markdown]
// ### Build the training pipeline

// %%
var trainingPipeline = preprocessingPipeline
    .Append(mlContext.MulticlassClassification.Trainers.SdcaNonCalibrated("Label", "Features"));

// %% [markdown]
// ### Build the post-processing pipeline
// > Map key (number) to value (string)

// %%
var postprocessingPipeline = trainingPipeline
    .Append(mlContext.Transforms.Conversion.MapKeyToValue("PredictedLabel"));

// %% [markdown]
// ## 1. Validate Model

// %%
#r "nuget:Microsoft.Data.Analysis"
using Microsoft.AspNetCore.Html;
using Microsoft.Data.Analysis;
// Out:
// Installed package Microsoft.Data.Analysis version 0.4.0

// %% [markdown]
// ### Loads Confusion Matrix Formatter (from csx, library or nuget, see Formatters.csx)

// %%
//#r "nuget:ApexCode.Interactive.Formatting,0.0.1-beta.5"
//using ApexCode.Interactive.Formatting;

#load "C:\Users\dcost\source\repos\SmartFireAlarm\SmartFireAlarm\Jupyter\Formatters.csx"
Formatters.Categories = new string[] { "FlashLight", "Infrared", "Day", "Lighter" };
Formatters.Register<DataFrame>();
Formatters.Register<List<TrainCatalogBase.CrossValidationResult<MulticlassClassificationMetrics>>>();
Formatters.Register<MulticlassClassificationMetrics>();

// %%
var crossValidationResults = mlContext.MulticlassClassification.CrossValidate(trainingData, postprocessingPipeline, numberOfFolds: 5, labelColumnName: "Label");
display(crossValidationResults.ToList())
// Out:
// <table><thead><th><b>CROSS-VALIDATION: multi-class classification</b></th><th><b>Average</b></th><th><b>Standard deviation</b></th><th><b>Confidence interval (95%)</b></th></thead><tbody><tr><td><b>MacroAccuracy</b></td><td>0.965</td><td>0.017</td><td>0.017</td></tr><tr><td><b>MicroAccuracy</b></td><td>0.964</td><td>0.012</td><td>0.012</td></tr><tr><td><b>LogLoss</b></td><td>2.484</td><td>2.863</td><td>2.805</td></tr><tr><td><b>LogLossReduction</b></td><td>-0.878</td><td>2.163</td><td>2.120</td></tr></tbody></table>

// %% [markdown]
// ### Permuation Feature Importance (PFI)

// %%
var modelForContributions = trainingPipeline.Fit(trainingData);
var transformedData = modelForContributions.Transform(testingData); // never do the PFI on training data!
var linearPredictor = modelForContributions.LastTransformer;

// %%
var pfi = mlContext.MulticlassClassification.PermutationFeatureImportance(predictionTransformer: linearPredictor, data: transformedData, permutationCount: 5);
var sortedMetrics = pfi
    .Select((metrics, index) => new { index, metrics.MicroAccuracy })
    .OrderByDescending(feature => Math.Abs(feature.MicroAccuracy.Mean))
    .Select(feature => feature.index);

// %%
var pfiDiagram = Chart.Plot(new Graph.Bar
    {
        x = sortedMetrics,
        y = featureColumns.Reverse(), 
        orientation = "h"
    });
var layout = new Layout.Layout()
{
    title = "Permuation Feature Importance (PFI)"
};
pfiDiagram.WithLayout(layout);
display(pfiDiagram);
// Out:
// <div id="d4cb7f2f-28bc-4f32-bc73-d86ce77c0a9e" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = require.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}}) || require;
//     xplotRequire(['plotly'], function(Plotly) {
//
//             var data = [{"type":"bar","x":[1,2,3,4,0,5],"y":["Day","Hour","Distance","Infrared","Luminosity","Temperature"],"orientation":"h"}];
//             var layout = {"title":"Permuation Feature Importance (PFI)"};
//             Plotly.newPlot('d4cb7f2f-28bc-4f32-bc73-d86ce77c0a9e', data, layout);
//
// });
// };
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     var script = document.createElement("script");
//     script.setAttribute("src", "https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js");
//     script.onload = function(){
//         renderPlotly();
//     };
//     document.getElementsByTagName("head")[0].appendChild(script);
// }
// else {
//     renderPlotly();
// }
// </script>

// %% [markdown]
// ## 2. Evaluate Model

// %% [markdown]
// ### Train the model

// %%
var model = postprocessingPipeline.Fit(trainingData);

// %% [markdown]
// ### Evaluate the model

// %%
var predictions = model.Transform(testingData);
var metrics = mlContext.MulticlassClassification.Evaluate(predictions, "Label", "Score", "PredictedLabel");

// %%
Formatters.Register<MulticlassClassificationMetrics>();
metrics
// Out:
// <table><thead><th><b>EVALUATION: multi-class classification</b></th><th><b>Class</b></th><th><b>Value</b></th><th><b>Note</b></th></thead><tbody><tr><td><b>MacroAccuracy</b></td><td></td><td>0.974</td><td>the closer to 1, the better</td></tr><tr><td><b>MicroAccuracy</b></td><td></td><td>0.982</td><td>the closer to 1, the better</td></tr><tr><td><b>LogLoss</b></td><td></td><td>24.022</td><td>the closer to 0, the better</td></tr><tr><td rowspan="5"><b>LogLoss per Class</b></td></tr><tr><td>FlashLight</td><td>30.761</td><td>the closer to 0, the better</td></tr><tr><td>Infrared</td><td>17.907</td><td>the closer to 0, the better</td></tr><tr><td>Day</td><td>32.940</td><td>the closer to 0, the better</td></tr><tr><td>Lighter</td><td>0.000</td><td>the closer to 0, the better</td></tr></tbody></table>

// %% [markdown]
// ### Confusion matrix

// %%
Formatters.Register<ConfusionMatrix>();
display(metrics.ConfusionMatrix);
// Out:
// <table style="margin: 50px; "><tbody><tr style="background-color: transparent"><td colspan="2" rowspan="2" style="padding: 8px; background-color: lightsteelblue; text-align: center; ">Confusion Matrix</td><td colspan="4" style="padding: 8px; background-color: lightsteelblue; text-align: center; ">Predicted</td><td style="padding: 8px; background-color: lightsteelblue; "></td></tr><tr style="background-color: transparent"><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">FlashLight</td><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">Infrared</td><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">Day</td><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">Lighter</td><td style="padding: 8px; background-color: lightsteelblue; ">Recall</td></tr><tr style="background-color: transparent"><td rowspan="4" style="padding: 8px; background-color: lightsteelblue; ">Truth</td><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">FlashLight</td><td style="padding: 8px; "><div class="dni-plaintext">45</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">1</div></td></tr><tr style="background-color: transparent"><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">Infrared</td><td style="padding: 8px; "><div class="dni-plaintext">3</div></td><td style="padding: 8px; "><div class="dni-plaintext">26</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">0.8966</div></td></tr><tr style="background-color: transparent"><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">Day</td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">64</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">1</div></td></tr><tr style="background-color: transparent"><td style="padding: 8px; font-weight: bold; background-color: #E3EAF3; ">Lighter</td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">0</div></td><td style="padding: 8px; "><div class="dni-plaintext">29</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">1</div></td></tr><tr style="background-color: transparent"><td colspan="2" style="padding: 8px; background-color: lightsteelblue; ">Precision</td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">0.9375</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">1</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">1</div></td><td style="padding: 8px; background-color: #E3EAF3; "><div class="dni-plaintext">1</div></td><td style="padding: 8px; background-color: #E3EAF3; ">total = 167</td></tr></tbody></table>

// %% [markdown]
// ### Save the trained model

// %%
mlContext.Model.Save(model, trainingData.Schema, "model.zip");
